# %%
from JSON_parser import *
id = "a414369792531f3d9fe4d24aef91dd23"
lastfm_dir = '../dataset/lastfm/'
extension = "_analysis.json"
song = lastfm_dir + "/" + id +"/"+ id + extension

# Get the data
print(song)
chords_data = get_JSON_files(song)  # Your working function unchanged
structure_data = get_structure_data(song)  # Get the additional data
# Out:
# ../dataset/lastfm//a414369792531f3d9fe4d24aef91dd23/a414369792531f3d9fe4d24aef91dd23_analysis.json

# %%
import plotMe 
plotMe.plot_combined_chord_structure_map(chords_data, structure_data, beats_per_row=32)
print("done!")
# Out:
# done!

# %%
# Listen to the song
collection = "lastfm"
song_path = "/mnt/Aimir_HD/"+collection+"/"+"audio/"+id+".mp3"
print(song_path)

from IPython.display import Audio
Audio(song_path)
# Out:
# /mnt/Aimir_HD/lastfm/audio/a414369792531f3d9fe4d24aef91dd23.mp3
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
